# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Site data Validation

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading data
dataset = pd.read_csv('/content/drive/MyDrive/Personalisation/bq-results-20230707-122643-1688733557518.csv')
dataset
# Out:
#        tenant                timestamp                   site_id  \
# 0       airqo  2023-03-07 02:00:00 UTC  60d058c8048305120d2d6145
# 1       airqo  2023-03-08 07:00:00 UTC  60d058c8048305120d2d6145
# 2       airqo  2023-03-28 12:00:00 UTC  60d058c8048305120d2d6145
# 3       airqo  2023-03-10 16:00:00 UTC  60d058c8048305120d2d6145
# 4       airqo  2023-03-08 04:00:00 UTC  60d058c8048305120d2d6145
# ...       ...                      ...                       ...
# 250454  airqo  2023-02-21 12:00:00 UTC  60d058c8048305120d2d6155
# 250455  airqo  2023-02-23 03:00:00 UTC  60d058c8048305120d2d6155
# 250456  airqo  2023-02-25 00:00:00 UTC  60d058c8048305120d2d6155
# 250457  airqo  2023-02-05 06:00:00 UTC  60d058c8048305120d2d6155
# 250458  airqo  2023-02-27 03:00:00 UTC  60d058c8048305120d2d6155
#
#                             site_name           site_description  \
# 0       Civic Centre, Kampala Central                 NEMA House
# ...

# %%
# Checking for data types of the columns
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250459 entries, 0 to 250458
# Data columns (total 62 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   tenant                                      250459 non-null  object
#  1   timestamp                                   250459 non-null  object
#  2   site_id                                     250459 non-null  object
#  3   site_name                                   250459 non-null  object
#  4   site_description                            250459 non-null  object
#  5   site_latitude                               250459 non-null  float64
#  6   site_longitude                              250459 non-null  float64
#  7   site_altitude                               250459 non-null  float64
#  8   device_number                               250459 non-null  int64
# ...

# %%
# Checking for missing values
dataset.isnull()
# Out:
#         tenant  timestamp  site_id  site_name  site_description  \
# 0        False      False    False      False             False
# 1        False      False    False      False             False
# 2        False      False    False      False             False
# 3        False      False    False      False             False
# 4        False      False    False      False             False
# ...        ...        ...      ...        ...               ...
# 250454   False      False    False      False             False
# 250455   False      False    False      False             False
# 250456   False      False    False      False             False
# 250457   False      False    False      False             False
# 250458   False      False    False      False             False
#
#         site_latitude  site_longitude  site_altitude  device_number  \
# 0               False           False          False          False
# ...

# %%
# Displaying only columns with missing values
dataset.columns[dataset.isnull().any()]
# Out:
# Index(['device_id', 'device_latitude', 'device_longitude', 'device_battery',
#        'device_altitude', 'device_temperature', 'device_humidity', 'pm2_5',
#        's1_pm2_5', 's2_pm2_5', 'pm2_5_raw_value', 'pm2_5_calibrated_value',
#        'pm10', 's1_pm10', 's2_pm10', 'pm10_raw_value', 'pm10_calibrated_value',
#        'no2', 'no2_raw_value', 'no2_calibrated_value', 'pm1', 'pm1_raw_value',
#        'pm1_calibrated_value', 'temperature', 'humidity', 'wind_speed',
#        'atmospheric_pressure', 'radiation', 'vapor_pressure', 'wind_gusts',
#        'precipitation', 'wind_direction', 'satellites', 'hdop',
#        'site_bearing_to_kampala_center', 'site_distance_to_kampala_center',
#        'site_distance_to_nearest_tertiary_road',
#        'site_distance_to_nearest_primary_road',
#        'site_distance_to_nearest_road',
#        'site_distance_to_nearest_residential_road',
#        'site_distance_to_nearest_secondary_road',
#        'site_distance_to_nearest_unclassified_road'],
# ...

# %%
# Dropping fully empty columns
data = dataset.drop(['device_battery', 'no2', 'no2_raw_value', 'no2_calibrated_value', 'pm1', 'pm1_raw_value', 'pm1_calibrated_value'], axis=1)
data
# Out:
#        tenant                timestamp                   site_id  \
# 0       airqo  2023-03-07 02:00:00 UTC  60d058c8048305120d2d6145
# 1       airqo  2023-03-08 07:00:00 UTC  60d058c8048305120d2d6145
# 2       airqo  2023-03-28 12:00:00 UTC  60d058c8048305120d2d6145
# 3       airqo  2023-03-10 16:00:00 UTC  60d058c8048305120d2d6145
# 4       airqo  2023-03-08 04:00:00 UTC  60d058c8048305120d2d6145
# ...       ...                      ...                       ...
# 250454  airqo  2023-02-21 12:00:00 UTC  60d058c8048305120d2d6155
# 250455  airqo  2023-02-23 03:00:00 UTC  60d058c8048305120d2d6155
# 250456  airqo  2023-02-25 00:00:00 UTC  60d058c8048305120d2d6155
# 250457  airqo  2023-02-05 06:00:00 UTC  60d058c8048305120d2d6155
# 250458  airqo  2023-02-27 03:00:00 UTC  60d058c8048305120d2d6155
#
#                             site_name           site_description  \
# 0       Civic Centre, Kampala Central                 NEMA House
# ...

# %%
# Select the columns you want to display
select_columns = ['site_name', 'site_longitude', 'site_latitude', 'pm2_5']

# Use the DataFrame indexing to extract the selected columns
df = data[select_columns]
df
# Out:
#                             site_name  site_longitude  site_latitude  \
# 0       Civic Centre, Kampala Central          32.590        0.31400
# 1       Civic Centre, Kampala Central          32.590        0.31400
# 2       Civic Centre, Kampala Central          32.590        0.31400
# 3       Civic Centre, Kampala Central          32.590        0.31400
# 4       Civic Centre, Kampala Central          32.590        0.31400
# ...                               ...             ...            ...
# 250454      Bukasa, Kira Municipality          32.615        0.29875
# 250455      Bukasa, Kira Municipality          32.615        0.29875
# 250456      Bukasa, Kira Municipality          32.615        0.29875
# 250457      Bukasa, Kira Municipality          32.615        0.29875
# 250458      Bukasa, Kira Municipality          32.615        0.29875
#
#             pm2_5
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# ...

# %%
# Displaying only columns with missing values
df.columns[df.isnull().any()]
# Out:
# Index(['pm2_5'], dtype='object')

# %%
# Dropping missing values
df.dropna(subset=['pm2_5'], inplace=True)
df
# Out:
#                         site_name  site_longitude  site_latitude      pm2_5
# 504               Rubaga, Kampala       32.553682       0.295314  53.227143
# 505               Rubaga, Kampala       32.553682       0.295314  51.940116
# 506               Rubaga, Kampala       32.553682       0.295314  31.805114
# 507               Rubaga, Kampala       32.553682       0.295314  51.213023
# 508               Rubaga, Kampala       32.553682       0.295314  10.283750
# ...                           ...             ...            ...        ...
# 250454  Bukasa, Kira Municipality       32.615000       0.298750  28.766628
# 250455  Bukasa, Kira Municipality       32.615000       0.298750  48.872955
# 250456  Bukasa, Kira Municipality       32.615000       0.298750  39.800341
# 250457  Bukasa, Kira Municipality       32.615000       0.298750  37.814419
# 250458  Bukasa, Kira Municipality       32.615000       0.298750  19.081111
#
# [193577 rows x 4 columns]

# %%
# Calculating the mean pm2_5 for each site
pm2_5_mean = df.groupby(["site_name", "site_longitude", "site_latitude"])["pm2_5"].mean()
df1 = pm2_5_mean.to_frame().reset_index()
df1
# Out:
#                                     site_name  site_longitude  site_latitude  \
# 0                              Banda, Kampala       32.635306       0.341674
# 1                    Bbuto, Kira Municipality       32.672980       0.392050
# 2                   Bukasa, Kira Municipality       32.615000       0.298750
# 3                           Bukoto I, Kawempe       32.591000       0.351700
# 4                            Butabika, Nakawa       32.651449       0.307780
# 5                   Buwate, Kira Municipality       32.620270       0.405320
# 6                         Bweyogerere, Wakiso       32.677810       0.354825
# 7                 City parents primary school       32.565726       0.306112
# 8                             Ggaba, Makindye       32.636860       0.257760
# 9                   Kabalagala town, Makindye       32.600740       0.298330
# 10                           Kalerwe, Kawempe       32.573000       0.356400
# ...

# %%
# !pip install gmaps
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.5 MB/s eta 0:00:00
# ...
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076082 sha256=4872315ac21edad77d255250801942d2521d48dc665e9b5ccb5e2707401b56cf
#   Stored in directory: /root/.cache/pip/wheels/b3/c2/dc/48b3ef16c2184dae51a003f17eb5d065bbbf1af3437d9f14e3
# Successfully built gmaps
# ...

# %%
# Visualising the above data
# Import the necessary libraries
import folium
import gmaps

# Configure the Google Maps API
gmaps.configure(api_key="AIzaSyCjnhKVKIils01JNrEfMgSZFGGoMstaCWc")

# Create a map.
map = folium.Map(location=[0.40532, 32.67781], zoom_start=3)

# Add markers to the map.
for i in range(len(df1)):

  marker = folium.Marker([df1["site_latitude"][i], df1["site_longitude"][i]], popup=df1["site_name"][i], label=df1['pm2_5'][i])
  marker.add_to(map)

# Display the map.
map.save("map.html")

# %%
import pandas as pd
import numpy as np

# Define a function to get a random value from a group
def get_random_value(group):
    return group.sample(random_state=30).iloc[0]

def generate_random_pm2_5(dataframe):
    random_pm2_5 = df.groupby(['site_name', 'site_longitude', 'site_latitude'])['pm2_5'].apply(get_random_value)
    df_final = random_pm2_5.reset_index()
    return df_final

df_final = generate_random_pm2_5(df)

# Print the result
df_final
# Out:
#                                     site_name  site_longitude  site_latitude  \
# 0                              Banda, Kampala       32.635306       0.341674
# 1                    Bbuto, Kira Municipality       32.672980       0.392050
# 2                   Bukasa, Kira Municipality       32.615000       0.298750
# 3                           Bukoto I, Kawempe       32.591000       0.351700
# 4                            Butabika, Nakawa       32.651449       0.307780
# 5                   Buwate, Kira Municipality       32.620270       0.405320
# 6                         Bweyogerere, Wakiso       32.677810       0.354825
# 7                 City parents primary school       32.565726       0.306112
# 8                             Ggaba, Makindye       32.636860       0.257760
# 9                   Kabalagala town, Makindye       32.600740       0.298330
# 10                           Kalerwe, Kawempe       32.573000       0.356400
# ...

# %%
df_final['pm2_5'].max()
# Out:
# 301.621625

# %%
# Giving the correlating comment to the pm2_5 values
def get_comment(df_final):
    if df_final['pm2_5'] <= 12:
        return 'Good'
    elif df_final['pm2_5'] > 12 and df_final['pm2_5'] <= 35:
        return 'Moderate'
    elif df_final['pm2_5'] > 35 and df_final['pm2_5'] <= 55:
        return 'Unhealthy For Sensitive Groups'
    elif df_final['pm2_5'] > 55 and df_final['pm2_5'] <= 150:
        return 'Unhealthy'
    elif df_final['pm2_5'] > 150 and df_final['pm2_5'] <= 250:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

df_final['Comment'] = df_final.apply(get_comment, axis=1)

dx = df_final.drop('site_name', axis=1)
dx
# Out:
#     site_longitude  site_latitude       pm2_5                         Comment
# 0        32.635306       0.341674   11.860426                            Good
# 1        32.672980       0.392050   54.501974  Unhealthy For Sensitive Groups
# 2        32.615000       0.298750   11.549524                            Good
# 3        32.591000       0.351700   95.570385                       Unhealthy
# 4        32.651449       0.307780   55.584600                       Unhealthy
# 5        32.620270       0.405320  122.097027                       Unhealthy
# 6        32.677810       0.354825   52.531000  Unhealthy For Sensitive Groups
# 7        32.565726       0.306112   47.452100  Unhealthy For Sensitive Groups
# 8        32.636860       0.257760   38.179615  Unhealthy For Sensitive Groups
# 9        32.600740       0.298330   29.822375                        Moderate
# 10       32.573000       0.356400  236.628243                  Very Unhealthy
# ...

# %%
# Number and count of the comments
import seaborn as sns
sns.countplot(y = 'Comment', data=dx)
# Out:
# <Axes: xlabel='count', ylabel='Comment'>

# %% [markdown]
# ### User data validation

# %%
import pandas as pd

dataframe = pd.read_csv('/content/drive/MyDrive/Personalisation/user_data (1).csv')
dataframe
# Out:
#                   Name Date of Birth  Longitude  Latitude Health_Conditions  \
# 0          Brenda York    1989-08-15  32.256407  0.215141              None
# 1          Stacy Davis    2004-03-07  31.621517  0.251672       Lung cancer
# 2        Erica Johnson    1965-01-23  32.252161  0.262325         Pneumonia
# 3       Lawrence Baker    1974-09-21  32.363906  0.293627              None
# 4        Chloe Bradley    1963-12-28  32.074105  0.204387            Asthma
# ...                ...           ...        ...       ...               ...
# 1995   Cynthia Merritt    1987-06-01  32.258125  0.269074        Bronchitis
# 1996   Carlos Mitchell    1990-06-25  32.477388  0.232147              None
# 1997    Joseph Stevens    2001-02-23  31.942709  0.207624         Pneumonia
# 1998    William Foster    1975-01-12  31.648841  0.236469              None
# 1999  Barbara Villegas    1982-06-23  32.413118  0.222207           Chronic
#
#      Health_Status Activities
# ...

# %%
dataframe['Health_Conditions'].unique()
# Out:
# array(['None', ' Lung cancer', 'Pneumonia', 'Asthma', 'Chronic',
#        'High Blood Pressure', 'Bronchitis'], dtype=object)

# %%
dataframe.columns
# Out:
# Index(['Name', 'Date of Birth', 'Longitude', 'Latitude', 'Health_Conditions',
#        'Health_Status', 'Activities', 'Age'],
#       dtype='object')

# %%
# Calculating and adding the age column
from datetime import datetime
# Convert 'Date_of_Birth' column to datetime
dataframe['Date of Birth'] = pd.to_datetime(dataframe['Date of Birth'])

# Calculate age
current_year = datetime.now().year
dataframe['Age'] = current_year - dataframe['Date of Birth'].dt.year

# Print the DataFrame
dataframe
# Out:
#                   Name Date of Birth  Longitude  Latitude Health_Conditions  \
# 0          Brenda York    1989-08-15  32.256407  0.215141              None
# 1          Stacy Davis    2004-03-07  31.621517  0.251672       Lung cancer
# 2        Erica Johnson    1965-01-23  32.252161  0.262325         Pneumonia
# 3       Lawrence Baker    1974-09-21  32.363906  0.293627              None
# 4        Chloe Bradley    1963-12-28  32.074105  0.204387            Asthma
# ...                ...           ...        ...       ...               ...
# 1995   Cynthia Merritt    1987-06-01  32.258125  0.269074        Bronchitis
# 1996   Carlos Mitchell    1990-06-25  32.477388  0.232147              None
# 1997    Joseph Stevens    2001-02-23  31.942709  0.207624         Pneumonia
# 1998    William Foster    1975-01-12  31.648841  0.236469              None
# 1999  Barbara Villegas    1982-06-23  32.413118  0.222207           Chronic
#
#      Health_Status Activities  Age
# ...

# %%
# Select the columns you want to display
select_columns = ['Age', 'Health_Conditions', 'Health_Status', 'Activities', 'Longitude', 'Latitude']

# Use the DataFrame indexing to extract the selected columns
dt = dataframe[select_columns]
dt
# Out:
#       Age Health_Conditions Health_Status Activities  Longitude  Latitude
# 0      34              None       Healthy    Walking  32.256407  0.215141
# 1      19       Lung cancer          Sick    Walking  31.621517  0.251672
# 2      58         Pneumonia          Sick    Cycling  32.252161  0.262325
# 3      49              None       Healthy    Running  32.363906  0.293627
# 4      60            Asthma          Sick    Walking  32.074105  0.204387
# ...   ...               ...           ...        ...        ...       ...
# 1995   36        Bronchitis          Sick    Walking  32.258125  0.269074
# 1996   33              None       Healthy    Running  32.477388  0.232147
# 1997   22         Pneumonia          Sick   Swimming  31.942709  0.207624
# 1998   48              None       Healthy    Walking  31.648841  0.236469
# 1999   41           Chronic          Sick   Swimming  32.413118  0.222207
#
# [2000 rows x 6 columns]

# %% [markdown]
# ### Forming one dataset and Visualising it

# %%
# Joining the two dataframes using geopandas
import geopandas as gpd

# Convert the first dataframe to a GeoDataFrame with geometry column
dx1 = gpd.GeoDataFrame(dx, geometry=gpd.points_from_xy(dx.site_longitude, dx.site_latitude))

# Convert the second dataframe to a GeoDataFrame with geometry column
dt2 = gpd.GeoDataFrame(dt, geometry=gpd.points_from_xy(dt.Longitude, dt.Latitude))

# Set the CRS of both GeoDataFrames to WGS 84 (EPSG:4326)
dx1 = dx1.set_crs("EPSG:4326")
dt2 = dt2.set_crs("EPSG:4326")

# Perform a right join using sjoin_nearest
joined_df = gpd.sjoin_nearest(dx1, dt2, how="right", distance_col="distances")

# Print the first 5 rows of the result
joined_df.head()
# Out:
#    index_left  site_longitude  site_latitude      pm2_5  \
# 0          35       32.558017       0.269993  51.418222
# 1          44       32.529000       0.363000  30.428750
# 2          44       32.529000       0.363000  30.428750
# 3          44       32.529000       0.363000  30.428750
# 4          44       32.529000       0.363000  30.428750
#
#                           Comment  Age Health_Conditions Health_Status  \
# 0  Unhealthy For Sensitive Groups   34              None       Healthy
# 1                        Moderate   19       Lung cancer          Sick
# 2                        Moderate   58         Pneumonia          Sick
# 3                        Moderate   49              None       Healthy
# 4                        Moderate   60            Asthma          Sick
#
#   Activities  Longitude  Latitude                  geometry  distances
# 0    Walking  32.256407  0.215141  POINT (32.25641 0.21514)   0.306557
# ...

# %%
# Selecting columns needed for the model
final_df = joined_df.drop(['site_latitude', 'site_longitude', 'Latitude', 'Longitude', 'index_left', 'distances'], axis = 1)
final_df
# Out:
#           pm2_5                         Comment  Age Health_Conditions  \
# 0     51.418222  Unhealthy For Sensitive Groups   34              None
# 1     30.428750                        Moderate   19       Lung cancer
# 2     30.428750                        Moderate   58         Pneumonia
# 3     30.428750                        Moderate   49              None
# 4     30.428750                        Moderate   60            Asthma
# ...         ...                             ...  ...               ...
# 1995  30.428750                        Moderate   36        Bronchitis
# 1996  31.707727                        Moderate   33              None
# 1997  30.428750                        Moderate   22         Pneumonia
# 1998  30.428750                        Moderate   48              None
# 1999  31.707727                        Moderate   41           Chronic
#
#      Health_Status Activities                  geometry
# 0          Healthy    Walking  POINT (32.25641 0.21514)
# ...

# %%
# Number and count of the comments
import seaborn as sns
sns.countplot(y = 'Comment', data=final_df)
# Out:
# <Axes: xlabel='count', ylabel='Comment'>

# %%
import random

# rec_df = pd.DataFrame()
def Good():
    return 'Good day to be active outside' # even if sick

def Moderate(Health_Status):
    if Health_Status == 'Healthy':
        return 'Good day to be active outside'

    return random.choice(['Reduce prolonged/heavy outdoor exertion and Take more breaks during outdoor activities'])

def Unhealthy_For_Sensitive_Groups(Age, Health_Conditions):
    if Age > 45:
        return 'Reduce prolonged or heavy outdoor exertion'

    if Health_Conditions in ['Asthma', 'Pneumonia', 'Lung cancer', 'Bronchitis']:
        return 'keep quick relief medicine handy'

    return 'Good day to be active outside'

def unhealthy(Health_Status, Age):
    if Health_Status == 'Healthy' and Age < 45:
        return 'Reduce prolonged or heavy outdoor exertion'

    return random.choice(['Avoid prolonged/heavy outdoor exertion or reschedule for when air quality is better'])

def very_unhealthy(Health_Status, Age):
    if Health_Status == 'Healthy' and Age < 45:
        return random.choice(['Avoid prolonged/heavy outdoor exertion or reschedule for when air quality is better'])

    return random.choice(['Avoid all physical outdoor activities or reschedule for when air quality is better'])

def hazardous(Health_Status, Age):
    if Health_Status == 'Healthy' and Age < 45:
        return 'Remain indoors and keep activity levels low'

    return 'Avoid all physical outdoor activities'

def obtain_recommendation(Age, Health_Status, Health_Conditions, Comment):
    if Comment == 'Good':
        return Good()
    elif Comment == 'Moderate':
        return Moderate(Health_Status)
    elif Comment == 'Unhealthy For Sensitive Groups':
        return Unhealthy_For_Sensitive_Groups(Age, Health_Conditions)
    elif Comment == 'Unhealthy':
        return unhealthy(Health_Status, Age)
    elif Comment == 'Very unhealthy':
        return very_unhealthy(Health_Status, Age)
    elif Comment == 'Hazardous':
        return hazardous(Health_Status, Age)
    else:
        return 'No recommendation'

# %%
# Apply the recommendation function to each row in the DataFrame
def apply_recommendation(row):
    return obtain_recommendation(row['Age'], row['Health_Status'], row['Health_Conditions'], row['Comment'])

# Apply the recommendation function to each row in the DataFrame
final_df['Recommendation'] = final_df.apply(apply_recommendation, axis=1)

# Print the DataFrame with the added 'Recommendation' column
final_df
# Out:
#           pm2_5                         Comment  Age Health_Conditions  \
# 0     51.418222  Unhealthy For Sensitive Groups   34              None
# 1     30.428750                        Moderate   19       Lung cancer
# 2     30.428750                        Moderate   58         Pneumonia
# 3     30.428750                        Moderate   49              None
# 4     30.428750                        Moderate   60            Asthma
# ...         ...                             ...  ...               ...
# 1995  30.428750                        Moderate   36        Bronchitis
# 1996  31.707727                        Moderate   33              None
# 1997  30.428750                        Moderate   22         Pneumonia
# 1998  30.428750                        Moderate   48              None
# 1999  31.707727                        Moderate   41           Chronic
#
#      Health_Status Activities                  geometry  \
# 0          Healthy    Walking  POINT (32.25641 0.21514)
# ...

# %%
final_df['Recommendation'].unique()
# Out:
# array(['Good day to be active outside',
#        'Reduce prolonged/heavy outdoor exertion and Take more breaks during outdoor activities',
#        'keep quick relief medicine handy',
#        'Reduce prolonged or heavy outdoor exertion',
#        'Avoid prolonged/heavy outdoor exertion or reschedule for when air quality is better'],
#       dtype=object)

# %%
# Age Distribution
import matplotlib.pyplot as plt
plt.hist(x=final_df['Age'])
plt.title('Age Distribution\n')
plt.xlabel('Age')
plt.ylabel('Count')

plt.show()

# %%
# Number and count of Health Conditions
import seaborn as sns
sns.countplot(y = 'Health_Conditions', data=final_df)
# Out:
# <Axes: xlabel='count', ylabel='Health_Conditions'>

# %% [markdown]
# ### Model Development

# %%
# dataframe
final_df
# Out:
#           pm2_5                         Comment  Age Health_Conditions  \
# 0     51.418222  Unhealthy For Sensitive Groups   34              None
# 1     30.428750                        Moderate   19       Lung cancer
# 2     30.428750                        Moderate   58         Pneumonia
# 3     30.428750                        Moderate   49              None
# 4     30.428750                        Moderate   60            Asthma
# ...         ...                             ...  ...               ...
# 1995  30.428750                        Moderate   36        Bronchitis
# 1996  31.707727                        Moderate   33              None
# 1997  30.428750                        Moderate   22         Pneumonia
# 1998  30.428750                        Moderate   48              None
# 1999  31.707727                        Moderate   41           Chronic
#
#      Health_Status Activities                  geometry  \
# 0          Healthy    Walking  POINT (32.25641 0.21514)
# ...

# %%
# Encode input data
from sklearn.preprocessing import OrdinalEncoder

# Initialize OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

# Apply Ordinal Encoding to categorical columns
categorical_columns = ['Health_Conditions', 'Health_Status', 'Activities', 'Comment']
final_df[categorical_columns] = ordinal_encoder.fit_transform(final_df[categorical_columns])

final_df
# Out:
#           pm2_5  Comment  Age  Health_Conditions  Health_Status  Activities  \
# 0     51.418222      3.0   34                5.0            0.0         3.0
# 1     30.428750      1.0   19                0.0            1.0         3.0
# 2     30.428750      1.0   58                6.0            1.0         0.0
# 3     30.428750      1.0   49                5.0            0.0         1.0
# 4     30.428750      1.0   60                1.0            1.0         3.0
# ...         ...      ...  ...                ...            ...         ...
# 1995  30.428750      1.0   36                2.0            1.0         3.0
# 1996  31.707727      1.0   33                5.0            0.0         1.0
# 1997  30.428750      1.0   22                6.0            1.0         2.0
# 1998  30.428750      1.0   48                5.0            0.0         3.0
# 1999  31.707727      1.0   41                3.0            1.0         2.0
#
#                       geometry  \
# ...

# %%
from shapely.geometry import Point

# Extract latitude and longitude from the "geometry" column
final_df['Latitude'] = final_df['geometry'].apply(lambda point: point.y)
final_df['Longitude'] = final_df['geometry'].apply(lambda point: point.x)

# Drop the original "geometry" column
final_df.drop(['geometry'], axis=1, inplace=True)

final_df
# Out:
#           pm2_5  Comment  Age  Health_Conditions  Health_Status  Activities  \
# 0     51.418222      3.0   34                5.0            0.0         3.0
# 1     30.428750      1.0   19                0.0            1.0         3.0
# 2     30.428750      1.0   58                6.0            1.0         0.0
# 3     30.428750      1.0   49                5.0            0.0         1.0
# 4     30.428750      1.0   60                1.0            1.0         3.0
# ...         ...      ...  ...                ...            ...         ...
# 1995  30.428750      1.0   36                2.0            1.0         3.0
# 1996  31.707727      1.0   33                5.0            0.0         1.0
# 1997  30.428750      1.0   22                6.0            1.0         2.0
# 1998  30.428750      1.0   48                5.0            0.0         3.0
# 1999  31.707727      1.0   41                3.0            1.0         2.0
#
# ...

# %%
final_df['Recommendation'].dtype
# Out:
# dtype('O')

# %%
# Encode target data
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding to the "Recommendation" column
final_df['Recommendation'] = label_encoder.fit_transform(final_df['Recommendation'])
final_df
# Out:
#           pm2_5  Comment  Age  Health_Conditions  Health_Status  Activities  \
# 0     51.418222      3.0   34                5.0            0.0         3.0
# 1     30.428750      1.0   19                0.0            1.0         3.0
# 2     30.428750      1.0   58                6.0            1.0         0.0
# 3     30.428750      1.0   49                5.0            0.0         1.0
# 4     30.428750      1.0   60                1.0            1.0         3.0
# ...         ...      ...  ...                ...            ...         ...
# 1995  30.428750      1.0   36                2.0            1.0         3.0
# 1996  31.707727      1.0   33                5.0            0.0         1.0
# 1997  30.428750      1.0   22                6.0            1.0         2.0
# 1998  30.428750      1.0   48                5.0            0.0         3.0
# 1999  31.707727      1.0   41                3.0            1.0         2.0
#
#       Recommendation  Latitude  Longitude
# ...

# %%
dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
# Out:
# {'Avoid prolonged/heavy outdoor exertion or reschedule for when air quality is better': 0,
#  'Good day to be active outside': 1,
#  'Reduce prolonged or heavy outdoor exertion': 2,
#  'Reduce prolonged/heavy outdoor exertion and Take more breaks during outdoor activities': 3,
#  'keep quick relief medicine handy': 4}

# %%
# import necessary libraries
from sklearn.model_selection import train_test_split

# %%
# Create feature matrix and target vector
X = final_df.drop('Recommendation', axis = 1)
y = final_df['Recommendation']

# %%
# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# View the shape of the test data
X_test.shape
# Out:
# (600, 8)

# %%
# View the shape of the train data
X_train.shape
# Out:
# (1400, 8)

# %%
from sklearn.preprocessing import StandardScaler
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# Instantiate the model
LogReg = LogisticRegression(random_state=0)

# Fit Logistic Regression model
LogReg.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Predict test set results
y_pred = LogReg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
# Displaying Accuracy Score
acc = accuracy_score(y_test,y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
print('Accuracy :',acc)
# Out:
# Accuracy : 0.9383333333333334

# %% [markdown]
# ##### Validation

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
# Instantiate the model
knn_classifier = KNeighborsClassifier(n_neighbors = 5, metric='minkowski',p=2)

# Fit K-NN model
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predict test set results
y_pred_1 = knn_classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# Making the Confusion Matrix
cm1 = confusion_matrix(y_test, y_pred_1)
# Displaying Accuracy Score
acc1 = accuracy_score(y_test,y_pred_1)

ConfusionMatrixDisplay(confusion_matrix=cm1).plot();
print('Accuracy :',acc1)
# Out:
# Accuracy : 0.9316666666666666

# %% [markdown]
# #### Support Vector Machine

# %%
from sklearn.svm import SVC
# Fit Support Vector Machine model
svm = SVC(kernel = 'linear')
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Predict test set results
y_pred_2 = svm.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# Making the Confusion Matrix
cm2 = confusion_matrix(y_test, y_pred_2)
# Displaying Accuracy Score
acc2 = accuracy_score(y_test,y_pred_2)

ConfusionMatrixDisplay(confusion_matrix=cm2).plot();
print('Accuracy :',acc2)
# Out:
# Accuracy : 0.94

# %% [markdown]
# #### Decisionn Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate the model
classifier = DecisionTreeClassifier(random_state=42)

# Fit Decision Tree model
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Predict test set results
y_pred_3 = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# Making the Confusion Matrix
cm3 = confusion_matrix(y_test, y_pred_3)
# Displaying Accuracy Score
acc3 = accuracy_score(y_test,y_pred_3)

ConfusionMatrixDisplay(confusion_matrix=cm3).plot();
print('Accuracy :',acc3)
# Out:
# Accuracy : 0.995

# %% [markdown]
# #### Summary and Conlusion

# %% [markdown]
# From the above algorithm, Decision Tree was the best performing model with an accuracy of
#
#
# \begin{array}{|c|c|} \hline
# \textbf{Algorithm}\;(model) & \textbf{Accuracy} \\ \hline
# Logistic\;Regression  &   \\ \hline
# Decision\;Tree\;Classifier &  \\ \hline
# Support\;Vector\;Machines  &  \\ \hline
# KNN &  \\ \hline
# \end{array}
